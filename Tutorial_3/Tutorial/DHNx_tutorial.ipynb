# %% [markdown]
# <h1 style="text-align:center; color:green; font-size:48px;">
# DHNx TUTORIAL
# </h1>

# %% [markdown]
# #### Install libraries (if you did not do it before on the terminal)

# %%
# !pip install numpy==2.0.2 pandas==2.3.1
# !pip install matplotlib
# !pip install git+https://github.com/oemof/dhnx.git@dev
# !pip install osmnx==1.9.4 oemof.solph==0.5.6
# Out:
# Requirement already satisfied: numpy==2.0.2 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas==2.3.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pandas==2.3.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pandas==2.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pandas==2.3.1) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.3.1) (1.17.0)
# Requirement already satisfied: matplotlib in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting git+https://github.com/oemof/dhnx.git@dev
#   Cloning https://github.com/oemof/dhnx.git (to revision dev) to c:\users\maxen\appdata\local\temp\pip-req-build-zgjn6cpg
#   Resolved https://github.com/oemof/dhnx.git to commit 51a853a2c4c481f005cddd24e6aec9743203ce09
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas>=0.18.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (3.9.4)
# Requirement already satisfied: networkx in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (3.2.1)
# Requirement already satisfied: pillow in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (11.3.0)
# Requirement already satisfied: folium in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (0.20.0)
# Requirement already satisfied: addict in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (2.4.0)
# Requirement already satisfied: oemof.solph<0.6,>=0.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (0.5.6)
# Requirement already satisfied: scipy>=1.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from dhnx==0.0.4.dev0) (1.13.1)
# Requirement already satisfied: blinker in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (1.9.0)
# Requirement already satisfied: dill in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (0.4.0)
# Requirement already satisfied: numpy>=2.0.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (2.0.2)
# Requirement already satisfied: pyomo>=6.8.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (6.9.5)
# Requirement already satisfied: oemof.tools>=0.4.3 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (0.4.3)
# Requirement already satisfied: oemof.network>=0.5.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pandas>=0.18.0->dhnx==0.0.4.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pandas>=0.18.0->dhnx==0.0.4.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pandas>=0.18.0->dhnx==0.0.4.dev0) (2025.2)
# Requirement already satisfied: ply in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from pyomo>=6.8.0->oemof.solph<0.6,>=0.5->dhnx==0.0.4.dev0) (3.11)
# Requirement already satisfied: six>=1.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.18.0->dhnx==0.0.4.dev0) (1.17.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from folium->dhnx==0.0.4.dev0) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from folium->dhnx==0.0.4.dev0) (3.1.6)
# Requirement already satisfied: requests in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from folium->dhnx==0.0.4.dev0) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from folium->dhnx==0.0.4.dev0) (2025.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from jinja2>=2.9->folium->dhnx==0.0.4.dev0) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (3.2.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from matplotlib->dhnx==0.0.4.dev0) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->dhnx==0.0.4.dev0) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from requests->folium->dhnx==0.0.4.dev0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from requests->folium->dhnx==0.0.4.dev0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from requests->folium->dhnx==0.0.4.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from requests->folium->dhnx==0.0.4.dev0) (2025.11.12)
#   Running command git clone --filter=blob:none --quiet https://github.com/oemof/dhnx.git 'C:\Users\maxen\AppData\Local\Temp\pip-req-build-zgjn6cpg'
# Collecting osmnx==1.9.4
#   Using cached osmnx-1.9.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: oemof.solph==0.5.6 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (0.5.6)
# Collecting geopandas<0.15,>=0.12 (from osmnx==1.9.4)
#   Using cached geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: networkx<3.4,>=2.5 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from osmnx==1.9.4) (3.2.1)
# Collecting numpy<1.27,>=1.20 (from osmnx==1.9.4)
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Collecting pandas<2.3,>=1.1 (from osmnx==1.9.4)
#   Using cached pandas-2.2.3-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from osmnx==1.9.4) (2.32.5)
# Collecting shapely<2.1,>=2.0 (from osmnx==1.9.4)
#   Using cached shapely-2.0.7-cp39-cp39-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: blinker in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph==0.5.6) (1.9.0)
# Requirement already satisfied: dill in c:\users\maxen\anaconda3\envs\env_p2\lib\site-packages (from oemof.solph==0.5.6) (0.4.0)
# INFO: pip is looking at multiple versions of oemof-solph to determine which version is compatible with other requirements. This could take a while.
#
# The conflict is caused by:
#     osmnx 1.9.4 depends on numpy<1.27 and >=1.20
#     oemof-solph 0.5.6 depends on numpy>=2.0.0
#
# Additionally, some packages in these conflicts have no matching distributions available for your environment:
#     numpy
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
# ERROR: Cannot install oemof-solph==0.5.6 and osmnx==1.9.4 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import dhnx
import pandas as pd
import oemof.solph
from pyomo.environ import SolverFactory
# Out:
# Need to install geopandas to process osm data.
# Need to install shapely to download from osm.
# Need to install shapely to download from osm.
# Need to install geopandas to download from osm.
# Need to install osmnx to download from osm.
# Need to install CoolProp to use the hydraulic pre-calculation module.
# Need to install geopandas to process geometry data.
# Need to install shapely to process geometry.
# Need to install geopandas to process geometry data.
# Need to install shapely to process geometry.

# %% [markdown]
# # Example 1

# %% [markdown]
# ## 1.1 Create network and plot

# %%
# Initialize thermal network
network = dhnx.network.ThermalNetwork()

# Load town parameter
network = network.from_csv_folder(r"DHNx_files/Example_1/twn_data")

# Load investment parameter
invest_opt = dhnx.input_output.load_invest_options(r"DHNx_files/Example_1/invest_data")

# %%
# plot initial/given network
static_map = dhnx.plotting.StaticMap(network) # That's how DHNx plots the network
static_map.draw(background_map=False) # This line to show the network on a blank area.
plt.title('Given network') 

#Scatter plots to differentiate the consumers, producers and forks. 
plt.scatter(network.components.consumers['lon'], network.components.consumers['lat'],
            color='tab:green', label='consumers', zorder=2.5, s=50) 
plt.scatter(network.components.producers['lon'], network.components.producers['lat'],
            color='tab:red', label='producers', zorder=2.5, s=50)
plt.scatter(network.components.forks['lon'], network.components.forks['lat'],
            color='tab:grey', label='forks', zorder=2.5, s=50)
plt.text(-2, 32, 'P0', fontsize=14)
plt.text(82, 0, 'P1', fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# ## 1.2 Investment optimization of the network

# %%
# Optimize the investment data
network.optimize_investment(invest_options=invest_opt,  solver='glpk')
# Out:
# c:\Users\maxen\anaconda3\envs\env_P2\lib\site-packages\oemof\solph\flows\_flow.py:163: FutureWarning: For backward compatibility, the option investment overwrites the option nominal_value. Both options cannot be set at the same time.
#   warn(msg, FutureWarning)
# c:\Users\maxen\anaconda3\envs\env_P2\lib\site-packages\oemof\network\network\nodes.py:250: FutureWarning: Usage of oemof.network.Component is deprecated. Use oemof.network.Node instead.
#   warnings.warn(
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write C:\Users\maxen\AppData\Local\Temp\tmpvqzvhw78.glpk.raw --wglp C:\Users\maxen\AppData\Local\Temp\tmp1siwiykz.glpk.glp
#  --cpxlp C:\Users\maxen\AppData\Local\Temp\tmpqx4rpq71.pyomo.lp
# Reading problem data from 'C:\Users\maxen\AppData\Local\Temp\tmpqx4rpq71.pyomo.lp'...
# 245 rows, 226 columns, 546 non-zeros
# 1548 lines were read
# Writing problem data to 'C:\Users\maxen\AppData\Local\Temp\tmp1siwiykz.glpk.glp'...
# 1156 lines were written
# GLPK Simplex Optimizer 5.0
# 245 rows, 226 columns, 546 non-zeros
# Preprocessing...
# 219 rows, 208 columns, 494 non-zeros
# Scaling...
#  A: min|aij| =  1.000e-04  max|aij| =  1.000e+00  ratio =  1.000e+04
# GM: min|aij| =  3.051e-01  max|aij| =  3.278e+00  ratio =  1.075e+01
# EQ: min|aij| =  9.306e-02  max|aij| =  1.000e+00  ratio =  1.075e+01
# Constructing initial basis...
# Size of triangular part is 219
#       0: obj =  -4.020000000e+07 inf =   4.488e+06 (40)
#      39: obj =   2.507087609e+04 inf =   0.000e+00 (0)
# *    44: obj =   2.441041390e+04 inf =   1.330e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.3 Mb (314803 bytes)
# Writing basic solution to 'C:\Users\maxen\AppData\Local\Temp\tmpvqzvhw78.glpk.raw'...
# 480 lines were written
# INFO:root:Optimization successful...

# %%
network.optimize_investment(invest_options=invest_opt,  solver='cbc')
# Out:
# INFO:dhnx.optimization.optimization_models:Initialize the energy system
# INFO:dhnx.optimization.optimization_models:Create oemof objects
# INFO:dhnx.optimization.optimization_models:Producers, Consumers Nodes appended.
# c:\Users\maxen\anaconda3\envs\env_P2\lib\site-packages\oemof\solph\flows\_flow.py:163: FutureWarning: For backward compatibility, the option investment overwrites the option nominal_value. Both options cannot be set at the same time.
#   warn(msg, FutureWarning)
# c:\Users\maxen\anaconda3\envs\env_P2\lib\site-packages\oemof\network\network\nodes.py:250: FutureWarning: Usage of oemof.network.Component is deprecated. Use oemof.network.Node instead.
#   warnings.warn(
# INFO:dhnx.optimization.optimization_models:DHS Nodes appended.
# INFO:dhnx.optimization.optimization_models:Energysystem has been created
# INFO:dhnx.optimization.optimization_models:Build the operational model
# INFO:dhnx.optimization.optimization_models:Solve the optimization problem
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug  2 2025
#
# command line - C:\Users\maxen\anaconda3\envs\env_P2\Library\bin\cbc.exe -printingOptions all -import C:\Users\maxen\AppData\Local\Temp\tmpkekofx4g.pyomo.lp -stat=1 -solve -solu C:\Users\maxen\AppData\Local\Temp\tmpkekofx4g.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 59 (-186) rows, 56 (-170) columns and 172 (-374) elements
# Statistics for presolved model
#
#
# Problem has 59 rows, 56 columns (32 with objective) and 172 elements
# There are 8 singletons with objective
# Column breakdown:
# 24 of type 0.0->inf, 24 of type 0.0->up, 0 of type lo->inf,
# 8 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 0 of type 0.0->1.0
# Row breakdown:
# 5 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 6 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 48 of type L 0.0, 0 of type L 1.0,
# 0 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Presolve 59 (-186) rows, 56 (-170) columns and 172 (-374) elements
# Perturbing problem by 0.001% of 26321.48 - largest nonzero change 0.00098556296 ( 0.00077913645%) - largest zero change 0.00052147992
# 0  Obj 4020.4021 Primal inf 18785.502 (6)
# 31  Obj 24412.023
# 31  Obj 24410.414 Dual inf 0.00047520645 (1)
# 32  Obj 24410.414
# Optimal - objective value 24410.414
# After Postsolve, objective 24410.414, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 24410.4139 - 32 iterations time 0.002, Presolve 0.00
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.05
# INFO:root:Optimization successful...

# %% [markdown]
# ## 1.3 Results postprocessing and Plotting

# %%
# ####### Postprocessing and Plotting ###########
results_edges = network.results.optimization['components']['pipes']
print(results_edges[['from_node', 'to_node', 'hp_type', 'capacity',
                     'direction', 'costs', 'losses']])

results_edges.to_csv("Outputs/Ex1.results_edges.csv", index=True)

print('Objective value: ', network.results.optimization['oemof_meta']['objective'])

# assign new ThermalNetwork with invested pipes
twn_results = network
twn_results.components['pipes'] = results_edges[results_edges['capacity'] > 0.001]

# plot invested edges
static_map_2 = dhnx.plotting.StaticMap(twn_results)
static_map_2.draw(background_map=False)
plt.title('Result network')
plt.scatter(network.components.consumers['lon'], network.components.consumers['lat'],
            color='tab:green', label='consumers', zorder=2.5, s=50)
plt.scatter(network.components.producers['lon'], network.components.producers['lat'],
            color='tab:red', label='producers', zorder=2.5, s=50)
plt.scatter(network.components.forks['lon'], network.components.forks['lat'],
            color='tab:grey', label='forks', zorder=2.5, s=50)
plt.text(-2, 32, 'P0', fontsize=14)
plt.text(82, 0, 'P1', fontsize=14)
plt.legend()
plt.show()
# Out:
#       from_node      to_node     hp_type    capacity  direction       costs  \
# id
# 0   producers-0      forks-0  pipe-typ-A  115.072630          1  4602.90520
# 1   producers-1      forks-5  pipe-typ-A   86.049421          1  3441.97684
# 2       forks-0      forks-1  pipe-typ-A   33.013204          1   660.26408
# 3       forks-1      forks-2  pipe-typ-A   33.009902          1  1320.39608
# 4       forks-2      forks-3        None    0.000000          0     0.00000
# 5       forks-3      forks-4  pipe-typ-A   25.005001         -1   500.10002
# 6       forks-4      forks-5  pipe-typ-A   61.014703         -1  1220.29406
# 7       forks-5      forks-6  pipe-typ-A   25.017509          1  1501.05054
# 8       forks-6      forks-7  pipe-typ-A   25.010003          1  1500.60018
# 9       forks-7      forks-8        None    0.000000          0     0.00000
# 10      forks-8      forks-9  pipe-typ-A   12.003601         -1   480.14404
# 11      forks-9     forks-10  pipe-typ-A   12.004801         -1   240.09602
# 12     forks-10      forks-0  pipe-typ-A   82.036413         -1  4922.18478
# 13      forks-2  consumers-0  pipe-typ-A   15.001500          1   300.03000
# 14      forks-2  consumers-1  pipe-typ-A   18.001800          1   360.03600
# 15      forks-3  consumers-2  pipe-typ-A   25.002500          1   500.05000
# 16      forks-4  consumers-3  pipe-typ-A   36.003600          1   720.07200
# 17      forks-7  consumers-4  pipe-typ-A   25.002500          1   500.05000
# 18      forks-8  consumers-5  pipe-typ-A   12.001200          1   240.02400
# 19     forks-10  consumers-7  pipe-typ-A   20.002000          1   400.04000
# 20     forks-10  consumers-6  pipe-typ-A   50.005001          1  1000.10002
#
#       losses
# id
# 0   0.023015
# 1   0.017210
# 2   0.003301
# 3   0.006602
# 4   0.000000
# 5   0.002501
# 6   0.006101
# 7   0.007505
# 8   0.007503
# 9   0.000000
# 10  0.002401
# 11  0.001200
# 12  0.024611
# 13  0.001500
# 14  0.001800
# 15  0.002500
# 16  0.003600
# 17  0.002500
# 18  0.001200
# 19  0.002000
# 20  0.005001
# Objective value:  24410.41386

# %% [markdown]
# # Example 2

# %% [markdown]
# ## 2.1 Create and visualize the thermal network

# %%
# Initialize thermal network
network = dhnx.network.ThermalNetwork()

# Load town data file for town parameters
network = network.from_csv_folder(r"DHNx_files/Example_2/twn_data")

# Load investment parameter
invest_opt = dhnx.input_output.load_invest_options(r"DHNx_files/Example_2/invest_data")
# Out:
# No sequences found to create timeindex from

# %%
# Draw network
static_map = dhnx.plotting.StaticMap(network)
static_map.draw(background_map=False)
plt.title("Given network")
plt.show()

# %% [markdown]
# ## 2.2 investment optimization of the thermal network

# %%
# Execute investment optimization
network.optimize_investment(invest_options=invest_opt, write_lp_file=True, solver='glpk')
# Out:
# INFO:dhnx.optimization.optimization_models:Initialize the energy system
# INFO:dhnx.optimization.optimization_models:Create oemof objects
# INFO:dhnx.optimization.optimization_models:Producers, Consumers Nodes appended.
# c:\Users\maxen\anaconda3\envs\env_P2\lib\site-packages\oemof\solph\flows\_flow.py:163: FutureWarning: For backward compatibility, the option investment overwrites the option nominal_value. Both options cannot be set at the same time.
#   warn(msg, FutureWarning)
# c:\Users\maxen\anaconda3\envs\env_P2\lib\site-packages\oemof\network\network\nodes.py:250: FutureWarning: Usage of oemof.network.Component is deprecated. Use oemof.network.Node instead.
#   warnings.warn(
# INFO:dhnx.optimization.optimization_models:DHS Nodes appended.
# INFO:dhnx.optimization.optimization_models:Energysystem has been created
# INFO:dhnx.optimization.optimization_models:Build the operational model
# INFO:dhnx.optimization.optimization_models:Solve the optimization problem
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write C:\Users\maxen\AppData\Local\Temp\tmpi5vs4t8g.glpk.raw --wglp C:\Users\maxen\AppData\Local\Temp\tmpjgp4l8hi.glpk.glp
#  --cpxlp C:\Users\maxen\AppData\Local\Temp\tmpyxpf8dz7.pyomo.lp
# Reading problem data from 'C:\Users\maxen\AppData\Local\Temp\tmpyxpf8dz7.pyomo.lp'...
# 76 rows, 71 columns, 161 non-zeros
# 479 lines were read
# Writing problem data to 'C:\Users\maxen\AppData\Local\Temp\tmpjgp4l8hi.glpk.glp'...
# 353 lines were written
# GLPK Simplex Optimizer 5.0
# 76 rows, 71 columns, 161 non-zeros
# Preprocessing...
# 51 rows, 48 columns, 110 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 51
#       0: obj =   1.200000000e+01 inf =   1.020e+02 (4)
#       5: obj =   8.444100000e+01 inf =   0.000e+00 (0)
# *     9: obj =   7.317300000e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.1 Mb (102595 bytes)
# Writing basic solution to 'C:\Users\maxen\AppData\Local\Temp\tmpi5vs4t8g.glpk.raw'...
# 156 lines were written
# INFO:root:Optimization successful...
# INFO:dhnx.optimization.optimization_models:Store lp-file in C:\Users\maxen\.oemof\lp_files\DHNx.lp

# %% [markdown]
# ## 2.3 Postprocessing and Plotting

# %%
# get results
results_edges = network.results.optimization["components"]["pipes"]
print("*Results*")
print(results_edges)
print("")
print("Objective Value: ", network.results.optimization["oemof_meta"]["objective"])

# manually recalculate total costs
total_costs = (33 * 3.162 + 15 * 1 + 18 * 1 + 18 * 0.5) * 0.5
print("Costs re-calculation: ", total_costs)

# get indices which are existing or invested
ind = results_edges[results_edges["capacity"] > 0].index

# select invested edges
network_result = network
network_result.components["pipes"] = results_edges.loc[ind]

# Plotting the optimization result
static_map = dhnx.plotting.StaticMap(network)
static_map.draw(background_map=False)
plt.title('Optimization result')
plt.scatter(network.components.consumers['lon'], network.components.consumers['lat'],
            color='tab:green', label='consumers', zorder=2.5, s=50)
plt.scatter(network.components.producers['lon'], network.components.producers['lat'],
            color='tab:red', label='producers', zorder=2.5, s=50)
plt.scatter(network.components.forks['lon'], network.components.forks['lat'],
            color='tab:grey', label='forks', zorder=2.5, s=50)
plt.legend()
plt.show()
# Out:
# *Results*
#       from_node      to_node  length     hp_type  capacity  direction   costs  \
# id
# 0   producers-0      forks-0   4.000        None       0.0          0   0.000
# 1   producers-0      forks-1   3.162  pipe-typ-A      33.0          1  52.173
# 5       forks-0      forks-1   1.414        None       0.0          0   0.000
# 6       forks-0      forks-2   1.414        None       0.0          0   0.000
# 9       forks-1      forks-2   1.000  pipe-typ-A      18.0          1   9.000
# 10      forks-1  consumers-0   1.000  pipe-typ-A      15.0          1   7.500
# 12      forks-2  consumers-1   0.500  pipe-typ-A      18.0          1   4.500
#
#     losses
# id
# 0      0.0
# 1      0.0
# 5      0.0
# 6      0.0
# 9      0.0
# 10     0.0
# 12     0.0
#
# Objective Value:  73.173
# Costs re-calculation:  73.173
